# %%
import numpy as np
import pandas as pd
from sortasurvey.notebook import Survey, rank

# %% [markdown]
# ### The `Sample` class
#
# #### Functionality within the target selection process:
#
# But first, because it's easy and we already have all the required info, let's create the `Survey` first.

# %%
TKS = Survey(path_sample='info/TKS_sample.csv', path_survey='info/survey_info.csv', \
             path_priority='info/high_priority.csv', path_ignore='info/no_no.csv')

# %% [markdown]
# Initialization of a `Sample` requires one positional argument, the survey `program` of interest, and also has three optional, keyword arguments (`survey`=`None`, `path_init`=`info/TKS_sample.csv`, `path_final`=`None`). The main use of the `Sample` during the target selection process is directly after a program is selected. An instance of the `Sample` class is created at every iteration, which filters the most up-to-date, full survey sample (e.g., `info/TKS_sample.csv`) to address the requirements/needs for the specified `program`. If the survey is not `None`, the programs and sample attributes of the provided survey are copied and stored as attributes of the `Sample` class object. Finally, the method `Sample.get_vetted_science` is called and creates the filtered sample (as described above).

# %% [markdown]
# BLAH BLAH BLAH BLAH (I know)... you are probably asking why you should care? In short, it's because there are some neat, quick tricks to take the full sample and transform it to a possible sample of interest. For example, we can do what we just explained in a one-liner.

# %%
from sortasurvey.sample import Sample
# TKS Multis
program='SC2C'
TKS.candidates = TKS.sample.copy()
TKS.sciences = TKS.programs.copy()

sample = Sample(program, survey=TKS)
sample.query
# Out:
#         toi        tic  cps_name evol source  disp photo_vetting spec_vetting  \
# 0   1136.01  142276270   T001136   MS    qlp   CPC        passed       passed
# 1   1246.01  230127302   T001246   MS   spoc    PC        passed       passed
# 2   1339.01  269701147    191939   MS   spoc   CPC        passed       passed
# 3    561.01  377064495   T000561   MS   spoc   VPC        passed       passed
# 4   1812.02  207425167   T001812   MS   spoc    PC        passed   do observe
# 5   1726.01  130181866     63433   MS   spoc     P        passed       passed
# 6    266.01  164767175   HIP8152   MS   spoc    PC        passed       passed
# 7   2076.01   27491137   T002076   MS   spoc    PC        passed       passed
# 8    261.02   63898957      5976   MS   spoc    PC        passed            -
# 9   1670.02  441739020   T001670   MS   spoc    PC        passed       passed
# 10  1347.01  229747848   T001347   MS   spoc   PPC        passed       passed
# 11  1438.01  229650439   T001438   MS   spoc    PC        passed       passed
# 12  1453.01  198390247   T001453   MS    qlp  VPC-        passed       passed
# 13  1798.01  198153540   T001798   MS   spoc    PC        passed       passed
# 14  1269.01  198241702   T001269   MS   spoc    PC        passed       passed
# 15  1346.01  219852882   T001346   MS    qlp    PC        passed       passed
# 16  1803.01  144401492   T001803   MS   spoc    PC        passed       passed
# 17  1260.01  355867695  T001260E   MS   spoc   VPC        passed            -
# 18  1468.01  243185500   T001468   MS   spoc   VPC        passed       passed
# 19   736.01  181804752   T000736   MS   spoc   VPC        passed            -
# 20  1266.01  467179528   T001266   MS   spoc   VPC        passed       passed
# 21  1730.01  318022259  HIP34730   MS   spoc    PC        passed       passed
# 22  1782.01  160045097   T001782   MS   spoc   CPC        passed       passed
#
#     ao_vetting        ra  ...  in_SC2Bi  in_SC2Bii  in_SC2C  in_SC3  in_SC4  \
# 0       passed  192.1849  ...         0          0        0       0       0
# 1       passed  251.1165  ...         0          0        0       0       0
# 2       passed  302.0240  ...         0          0        0       0       0
# 3       passed  148.1856  ...         0          0        0       0       0
# 4   data taken  242.7477  ...         0          0        0       0       0
# 5       passed  117.4794  ...         0          0        0       0       0
# 6       passed   26.2096  ...         0          0        0       0       0
# 7            -  217.3927  ...         0          0        0       0       0
# 8            -   15.2176  ...         0          0        0       0       0
# 9            -  259.0173  ...         0          0        0       0       0
# 10      passed  280.3268  ...         0          0        0       0       0
# 11           -  280.9243  ...         0          0        0       0       0
# 12      passed  258.2238  ...         0          0        0       0       0
# 13      passed  211.0941  ...         0          0        0       0       0
# 14      passed  249.6971  ...         0          0        0       0       0
# 15      passed  256.6229  ...         0          0        0       0       0
# 16      passed  178.0466  ...         0          0        0       0       0
# 17           -  157.1459  ...         0          0        0       0       0
# 18           -   16.6541  ...         0          0        0       0       0
# 19           -  165.6915  ...         0          0        0       0       0
# 20      passed  197.9982  ...         0          0        0       0       0
# 21      passed  107.8664  ...         0          0        0       0       0
# 22  data taken  213.0800  ...         0          0        0       0       0
#
#     in_TOA  in_TOB         TSM  SC3_bin_rank    actual_cost
# 0        0       0  112.014259           1.0   19717.677514
# 1        0       0   41.545341           NaN   79295.982315
# 2        0       0  169.010628           1.0   15300.000000
# 3        0       0  137.053642           2.0   24538.185516
# 4        0       0   40.946472           NaN  133500.000000
# 5        0       0  206.323125           NaN   26400.000000
# 6        0       0   49.966530           NaN   27937.818175
# 7        0       0  158.404277           3.0   29739.831906
# 8        0       0   68.056789           NaN   35232.524419
# 9        0       0   23.355611           NaN   43022.184541
# 10       0       0   51.777341           3.0   77700.578904
# 11       0       0   71.975615           NaN   78708.855610
# 12       0       0   54.855361           NaN   84300.859913
# 13       0       0   41.230647           NaN   89008.984039
# 14       0       0   37.370721           NaN   98087.590445
# 15       0       0   33.009459           NaN  105443.995501
# 16       0       0   56.067095           4.0  113112.978270
# 17       0       0   61.395982           3.0  116440.044915
# 18       0       0   89.811884           1.0  128220.000000
# 19       0       0  115.017422           1.0  133500.000000
# 20       0       0   73.432286           3.0  133500.000000
# 21       0       0   80.591434           1.0  133500.000000
# 22       0       0   49.720812           NaN  133500.000000
#
# [23 rows x 105 columns]

# %% [markdown]
# Remember that the only requirement for the TKS multis program is more than one planet. Now if you look at the above list of TOIs, you may notice that there is only one entry (or TIC) per TOI. This is because the initialization calls `sample.get_vetted_science()`, which has a default keyword argument `drop_dup` set to `True`. For purposes of target selection, this is helpful to avoid double selections (when in reality, you are only observing the one star).
#
# So let's turn that off.

# %%
sample.get_vetted_science(drop_dup=False)
sample.query
# Out:
#         toi        tic  cps_name evol source   disp photo_vetting  \
# 0   1136.01  142276270   T001136   MS    qlp    CPC        passed
# 1   1136.02  142276270   T001136   MS   spoc    CPC        passed
# 2   1136.03  142276270   T001136   MS   spoc     PC        passed
# 3   1136.04  142276270   T001136   MS   spoc     PC        passed
# 4   1246.01  230127302   T001246   MS   spoc     PC        passed
# 5   1246.02  230127302   T001246   MS   spoc   VPC-        passed
# 6   1246.03  230127302   T001246   MS   spoc     PC        passed
# 7   1246.04  230127302   T001246   MS   spoc     PC        passed
# 8   1339.01  269701147    191939   MS   spoc    CPC        passed
# 9   1339.02  269701147    191939   MS   spoc     PC        passed
# 10  1339.03  269701147    191939   MS   spoc     PC        passed
# 11   561.01  377064495   T000561   MS   spoc    VPC        passed
# 12   561.02  377064495   T000561   MS   spoc    CPC        passed
# 13   561.03  377064495   T000561   MS   spoc     PC        passed
# 14  1812.02  207425167   T001812   MS   spoc     PC        passed
# 15  1812.03  207425167   T001812   MS    qlp     PC        passed
# 16  1726.01  130181866     63433   MS   spoc      P        passed
# 17  1726.02  130181866     63433   MS   spoc      P        passed
# 18   266.01  164767175   HIP8152   MS   spoc     PC        passed
# 19   266.02  164767175   HIP8152   MS   spoc   STPC        passed
# 20  2076.01   27491137   T002076   MS   spoc     PC        passed
# 21  2076.02   27491137   T002076   MS   spoc     PC        passed
# 22   261.02   63898957      5976   MS   spoc     PC        passed
# 23  1670.02  441739020   T001670   MS   spoc     PC        passed
# 24  1347.01  229747848   T001347   MS   spoc    PPC        passed
# 25  1347.02  229747848   T001347   MS   spoc     PC        passed
# 26  1438.01  229650439   T001438   MS   spoc     PC        passed
# 27  1438.02  229650439   T001438   MS   spoc     PC        passed
# 28  1453.01  198390247   T001453   MS    qlp   VPC-        passed
# 29  1453.02  198390247   T001453   MS   spoc     PC        passed
# 30  1798.01  198153540   T001798   MS   spoc     PC        passed
# 31  1798.02  198153540   T001798   MS   spoc     PC        passed
# 32  1269.01  198241702   T001269   MS   spoc     PC        passed
# 33  1269.02  198241702   T001269   MS   spoc     PC        passed
# 34  1346.01  219852882   T001346   MS    qlp     PC        passed
# 35  1346.02  219852882   T001346   MS   spoc     PC        passed
# 36  1803.01  144401492   T001803   MS   spoc     PC        passed
# 37  1803.02  144401492   T001803   MS   spoc    VPC        passed
# 38  1260.01  355867695  T001260E   MS   spoc    VPC        passed
# 39  1260.02  355867695  T001260E   MS   spoc    CPC        passed
# 40  1468.01  243185500   T001468   MS   spoc    VPC        passed
# 41  1468.02  243185500   T001468   MS   spoc  VPC+?        passed
# 42   736.01  181804752   T000736   MS   spoc    VPC        passed
# 43   736.02  181804752   T000736   MS   spoc    VPC        passed
# 44  1266.01  467179528   T001266   MS   spoc    VPC        passed
# 45  1266.02  467179528   T001266   MS   spoc    VPC        passed
# 46  1730.01  318022259  HIP34730   MS   spoc     PC        passed
# 47  1730.02  318022259  HIP34730   MS   spoc    PPC        passed
# 48  1782.01  160045097   T001782   MS   spoc    CPC        passed
# 49  1782.02  160045097   T001782   MS   spoc     PC        passed
#
#    spec_vetting  ao_vetting        ra  ...  in_SC2Bi  in_SC2Bii  in_SC2C  \
# 0        passed      passed  192.1849  ...         0          0        0
# 1        passed      passed  192.1849  ...         0          0        0
# 2        passed      passed  192.1849  ...         0          0        0
# 3        passed      passed  192.1849  ...         0          0        0
# 4        passed      passed  251.1165  ...         0          0        0
# 5        passed      passed  251.1165  ...         0          0        0
# 6        passed      passed  251.1165  ...         0          0        0
# 7        passed      passed  251.1165  ...         0          0        0
# 8        passed      passed  302.0240  ...         0          0        0
# 9        passed      passed  302.0240  ...         0          0        0
# 10       passed      passed  302.0240  ...         0          0        0
# 11       passed      passed  148.1856  ...         0          0        0
# 12       passed      passed  148.1856  ...         0          0        0
# 13       passed      passed  148.1856  ...         0          0        0
# 14   do observe  data taken  242.7477  ...         0          0        0
# 15   do observe  data taken  242.7477  ...         0          0        0
# 16       passed      passed  117.4794  ...         0          0        0
# 17       passed      passed  117.4794  ...         0          0        0
# 18       passed      passed   26.2096  ...         0          0        0
# 19       passed      passed   26.2096  ...         0          0        0
# 20       passed           -  217.3927  ...         0          0        0
# 21       passed           -  217.3927  ...         0          0        0
# 22            -           -   15.2176  ...         0          0        0
# 23       passed           -  259.0173  ...         0          0        0
# 24       passed      passed  280.3268  ...         0          0        0
# 25       passed      passed  280.3268  ...         0          0        0
# 26       passed           -  280.9243  ...         0          0        0
# 27       passed           -  280.9243  ...         0          0        0
# 28       passed      passed  258.2238  ...         0          0        0
# 29       passed      passed  258.2238  ...         0          0        0
# 30       passed      passed  211.0941  ...         0          0        0
# 31       passed      passed  211.0941  ...         0          0        0
# 32       passed      passed  249.6971  ...         0          0        0
# 33       passed      passed  249.6971  ...         0          0        0
# 34       passed      passed  256.6229  ...         0          0        0
# 35       passed      passed  256.6229  ...         0          0        0
# 36       passed      passed  178.0466  ...         0          0        0
# 37       passed      passed  178.0466  ...         0          0        0
# 38            -           -  157.1459  ...         0          0        0
# 39            -           -  157.1459  ...         0          0        0
# 40       passed           -   16.6541  ...         0          0        0
# 41       passed           -   16.6541  ...         0          0        0
# 42            -           -  165.6915  ...         0          0        0
# 43            -           -  165.6915  ...         0          0        0
# 44       passed      passed  197.9982  ...         0          0        0
# 45       passed      passed  197.9982  ...         0          0        0
# 46       passed      passed  107.8664  ...         0          0        0
# 47       passed      passed  107.8664  ...         0          0        0
# 48       passed  data taken  213.0800  ...         0          0        0
# 49       passed  data taken  213.0800  ...         0          0        0
#
#     in_SC3  in_SC4  in_TOA  in_TOB         TSM  SC3_bin_rank    actual_cost
# 0        0       0       0       0  112.014259           1.0   19717.677514
# 1        0       0       0       0  108.059619           NaN   19717.677514
# 2        0       0       0       0   71.379037           5.0   19717.677514
# 3        0       0       0       0   52.212648           NaN   19717.677514
# 4        0       0       0       0   41.545341           NaN   79295.982315
# 5        0       0       0       0   54.551569           2.0   79295.982315
# 6        0       0       0       0   36.806047           NaN   79295.982315
# 7        0       0       0       0   31.379221           3.0   79295.982315
# 8        0       0       0       0  169.010628           1.0   15300.000000
# 9        0       0       0       0  105.053607           NaN   15300.000000
# 10       0       0       0       0         NaN           NaN   15300.000000
# 11       0       0       0       0  137.053642           2.0   24538.185516
# 12       0       0       0       0   61.956060           1.0   24538.185516
# 13       0       0       0       0   66.327526           NaN   24538.185516
# 14       0       0       0       0   40.946472           NaN  133500.000000
# 15       0       0       0       0   47.470833           NaN  133500.000000
# 16       0       0       0       0  206.323125           NaN   26400.000000
# 17       0       0       0       0  219.431352           NaN   26400.000000
# 18       0       0       0       0   49.966530           NaN   27937.818175
# 19       0       0       0       0   31.380170           NaN   27937.818175
# 20       0       0       0       0  158.404277           3.0   29739.831906
# 21       0       0       0       0  133.746592           1.0   29739.831906
# 22       0       0       0       0   68.056789           NaN   35232.524419
# 23       0       0       0       0   23.355611           NaN   43022.184541
# 24       0       0       0       0   51.777341           3.0   77700.578904
# 25       0       0       0       0   21.391666           NaN   77700.578904
# 26       0       0       0       0   71.975615           NaN   78708.855610
# 27       0       0       0       0   38.942118           NaN   78708.855610
# 28       0       0       0       0   54.855361           NaN   84300.859913
# 29       0       0       0       0    4.035571           5.0   84300.859913
# 30       0       0       0       0   41.230647           NaN   89008.984039
# 31       0       0       0       0    5.927046           2.0   89008.984039
# 32       0       0       0       0   37.370721           NaN   98087.590445
# 33       0       0       0       0   27.407378           NaN   98087.590445
# 34       0       0       0       0   33.009459           NaN  105443.995501
# 35       0       0       0       0   42.676000           NaN  105443.995501
# 36       0       0       0       0   56.067095           4.0  113112.978270
# 37       0       0       0       0   73.108809           NaN  113112.978270
# 38       0       0       0       0   61.395982           3.0  116440.044915
# 39       0       0       0       0   57.623273           NaN  116440.044915
# 40       0       0       0       0   89.811884           1.0  128220.000000
# 41       0       0       0       0    9.605173           3.0  128220.000000
# 42       0       0       0       0  115.017422           1.0  133500.000000
# 43       0       0       0       0   17.592066           NaN  133500.000000
# 44       0       0       0       0   73.432286           3.0  133500.000000
# 45       0       0       0       0   28.700033           NaN  133500.000000
# 46       0       0       0       0   80.591434           1.0  133500.000000
# 47       0       0       0       0    6.262148           5.0  133500.000000
# 48       0       0       0       0   49.720812           NaN  133500.000000
# 49       0       0       0       0   35.457001           NaN  133500.000000
#
# [50 rows x 105 columns]

# %% [markdown]
# Now you can see that the number of rows more than doubled, which is a good sanity check for planet multiplicity! You might also notice that the sample is already prioritized, with systems with the highest planet multiplicity are up at the top. TOIs 1136 and 1246 both have 4 planet candidates, but 1136 is ranked first, hmm. SC2C sorts by planet multiplicity and then by the "actual_cost" of the target, where cheaper targets are ranked more highly. Here the selection process isn't relevant, but fortunately it still calculates the cost (i.e. exposure time) of targets and  should only depend on the magnitude (and possibly existing observations) in this case.

# %%
# TOI 1136
index = sample.query.index[sample.query['toi'] == 1136.03].tolist()[0]
cost = sample.query.loc[index,'actual_cost']         # exposure times are calculated in seconds
print('The cost for TOI 1136 is %.2f hours'%(cost/60./60.))
# Out:
# The cost for TOI 1136 is 5.48 hours

# %%
# TOI 1246
index = sample.query.index[sample.query['toi'] == 1246.02].tolist()[0]
cost = sample.query.loc[index,'actual_cost']
print('The cost for TOI 1246 is %.2f hours'%(cost/60./60.))
# Out:
# The cost for TOI 1246 is 22.03 hours

# %% [markdown]
# As you can see, currently TOI 1246 would require ~4x the amount of telescope time to acquire the program's goals ($nobs=100$) and therefore ranked the correct target first! In the target selection iterations, the built-in method `get_highest_priority` is called, which returns the highest ranked star for that program that has not yet been selected by the program. Here, it should return the first...

# %%
pick = sample.get_highest_priority()
print(pick.toi)
# Out:
# 1136.01

# %% [markdown]
# Yay!
